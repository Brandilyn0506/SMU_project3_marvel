# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
import json

# %%
data = "data_copy/final_df.csv"

df = pd.read_csv(data)
df.head(20)
# Out:
#     Unnamed: 0              Name Alignment  Intelligence_x  Strength  Speed  \
# 0            0            A-Bomb      good              38       100     17
# 1            1        Abe Sapien      good              88        14     35
# 2            2          Abin Sur      good              50        90     53
# 3            3       Abomination       bad              63        80     53
# 4            4           Abraxas       bad              88       100     83
# 5            5       Adam Monroe      good              63        10     12
# 6            6      Adam Strange      good               1         1      1
# 7            7         Agent Bob      good              10         8     13
# 8            8        Agent Zero      good              75        28     38
# 9            9        Air-Walker       bad              50        85    100
# 10          10        Alan Scott      good              63        80     23
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#           Name Alignment  Intelligence_x  Strength  Speed  Durability_x  \
# 0       A-Bomb      good              38       100     17            80
# 1   Abe Sapien      good              88        14     35            42
# 2     Abin Sur      good              50        90     53            64
# 3  Abomination       bad              63        80     53            90
# 4      Abraxas       bad              88       100     83            99
#
#    Power  Combat  Total Gender  ... Web Creation Reality Warping Odin Force  \
# 0     17      64    316   Male  ...        False           False      False
# 1     35      85    299   Male  ...        False           False      False
# 2     84      65    406   Male  ...        False           False      False
# 3     55      95    436   Male  ...        False           False      False
# 4    100      56    526   Male  ...        False           False      False
#
#   Symbiote Costume Speed Force  Phoenix Force  Molecular Dissipation  \
# ...

# %%
columns = df.columns
for c in columns:
    print (c)
# Out:
# Name
# Alignment
# Intelligence_x
# Strength
# Speed
# Durability_x
# Power
# Combat
# Total
# Gender
# EyeColor
# Race
# HairColor
# Publisher
# SkinColor
# Height
# Weight
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# Element Control
# Phasing
# ...

# %%
df.count()
# Out:
# Name                     534
# Alignment                531
# Intelligence_x           534
# Strength                 534
# Speed                    534
#                         ...
# Phoenix Force            534
# Molecular Dissipation    534
# Vision - Cryo            534
# Omnipresent              534
# Omniscient               534
# Length: 182, dtype: int64

# %%
df.drop(['Intelligence_x', 'Strength', 'Speed', 'Durability_x', 'Power', 'Total', 'EyeColor', 'Race', 'HairColor', 'Publisher', 'Height', 'Weight', 'Agility'], axis=1, inplace=True)

# %%
df.head()
# Out:
#           Name Alignment  Combat Gender SkinColor  Accelerated Healing  \
# 0       A-Bomb      good      64   Male         -                 True
# 1   Abe Sapien      good      85   Male      blue                 True
# 2     Abin Sur      good      65   Male       red                False
# 3  Abomination       bad      95   Male         -                 True
# 4      Abraxas       bad      56   Male         -                False
#
#    Lantern Power Ring  Dimensional Awareness  Cold Resistance  Stealth  ...  \
# 0               False                  False            False    False  ...
# 1               False                  False             True    False  ...
# 2                True                  False            False    False  ...
# 3               False                  False            False    False  ...
# 4               False                   True            False    False  ...
#
#    Web Creation  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# ...

# %%
small_df = df[["Gender", "Alignment", "Name"]]

# %%
small_df.head()
# Out:
#   Gender Alignment         Name
# 0   Male      good       A-Bomb
# 1   Male      good   Abe Sapien
# 2   Male      good     Abin Sur
# 3   Male       bad  Abomination
# 4   Male       bad      Abraxas

# %%
small_df.sort_values(by=["Gender"], inplace=False)
small_df
# Out:
#      Gender Alignment             Name
# 0      Male      good           A-Bomb
# 1      Male      good       Abe Sapien
# 2      Male      good         Abin Sur
# 3      Male       bad      Abomination
# 4      Male       bad          Abraxas
# ..      ...       ...              ...
# 529    Male      good     Yellowjacket
# 530  Female      good  Yellowjacket II
# 531    Male      good             Ymir
# 532  Female      good          Zatanna
# 533    Male       bad             Zoom
#
# [534 rows x 3 columns]

# %%
small_df.sort_values(by=['Alignment'], inplace= True)
small_df
# Out:
# /Users/serendipitousfun/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     Gender Alignment        Name
# 533   Male       bad        Zoom
# 439   Male       bad    Sinestro
# 126   Male       bad     Carnage
# 433   Male       bad     Shocker
# 132   Male       bad   Chameleon
# ..     ...       ...         ...
# 310   Male   neutral     Man-Bat
# 491   Male   neutral        Toad
# 26    Male       NaN  Anti-Venom
# 88    Male       NaN   Blackwulf
# 495   Male       NaN   Trickster
#
# [534 rows x 3 columns]

# %%
small_df.dropna()
# Out:
#     Gender Alignment        Name
# 533   Male       bad        Zoom
# 439   Male       bad    Sinestro
# 126   Male       bad     Carnage
# 433   Male       bad     Shocker
# 132   Male       bad   Chameleon
# ..     ...       ...         ...
# 76    Male   neutral     Bizarro
# 273   Male   neutral  Juggernaut
# 417   Male   neutral     Sandman
# 310   Male   neutral     Man-Bat
# 491   Male   neutral        Toad
#
# [531 rows x 3 columns]

# %%
bad_male= small_df.groupby(["Alignment"]).get_group("bad")
bad_male
# Out:
#      Gender Alignment           Name
# 533    Male       bad           Zoom
# 439    Male       bad       Sinestro
# 126    Male       bad        Carnage
# 433    Male       bad        Shocker
# 132    Male       bad      Chameleon
# ..      ...       ...            ...
# 83   Female       bad    Black Mamba
# 337    Male       bad  Mister Freeze
# 474    Male       bad          Sylar
# 277    Male       bad       Kevin 11
# 77     Male       bad   Black Abbott
#
# [151 rows x 3 columns]

# %%
bad_male= bad_male.groupby(["Gender"]).get_group("Male")
bad_male
# Out:
#     Gender Alignment           Name
# 533   Male       bad           Zoom
# 439   Male       bad       Sinestro
# 126   Male       bad        Carnage
# 433   Male       bad        Shocker
# 132   Male       bad      Chameleon
# ..     ...       ...            ...
# 72    Male       bad       Bird-Man
# 337   Male       bad  Mister Freeze
# 474   Male       bad          Sylar
# 277   Male       bad       Kevin 11
# 77    Male       bad   Black Abbott
#
# [121 rows x 3 columns]

# %%
value = 1
bad_male['Value']= value
bad_male
# Out:
#     Gender Alignment           Name  Value
# 533   Male       bad           Zoom      1
# 439   Male       bad       Sinestro      1
# 126   Male       bad        Carnage      1
# 433   Male       bad        Shocker      1
# 132   Male       bad      Chameleon      1
# ..     ...       ...            ...    ...
# 72    Male       bad       Bird-Man      1
# 337   Male       bad  Mister Freeze      1
# 474   Male       bad          Sylar      1
# 277   Male       bad       Kevin 11      1
# 77    Male       bad   Black Abbott      1
#
# [121 rows x 4 columns]

# %%
bmale = bad_male.to_json(orient="records")
parsed = json.loads(bmale)
json.dumps(parsed, indent=4)
# Out:
# '[\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Zoom",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Sinestro",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Carnage",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Shocker",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Chameleon",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Changeling",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Chromos",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n        "Alignment": "bad",\n        "Name": "Cogliostro",\n        "Value": 1\n    },\n    {\n        "Gender": "Male",\n  
# ...

# %%
df.to_json(r'data_copy/bad_male.json')
