# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = "data copy/final_df.csv"

df = pd.read_csv(data)
df.head(20)
# Out:
#     Unnamed: 0              Name Alignment  Intelligence_x  Strength  Speed  \
# 0            0            A-Bomb      good              38       100     17
# 1            1        Abe Sapien      good              88        14     35
# 2            2          Abin Sur      good              50        90     53
# 3            3       Abomination       bad              63        80     53
# 4            4           Abraxas       bad              88       100     83
# 5            5       Adam Monroe      good              63        10     12
# 6            6      Adam Strange      good               1         1      1
# 7            7         Agent Bob      good              10         8     13
# 8            8        Agent Zero      good              75        28     38
# 9            9        Air-Walker       bad              50        85    100
# 10          10        Alan Scott      good              63        80     23
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#           Name Alignment  Intelligence_x  Strength  Speed  Durability_x  \
# 0       A-Bomb      good              38       100     17            80
# 1   Abe Sapien      good              88        14     35            42
# 2     Abin Sur      good              50        90     53            64
# 3  Abomination       bad              63        80     53            90
# 4      Abraxas       bad              88       100     83            99
#
#    Power  Combat  Total Gender  ... Web Creation Reality Warping Odin Force  \
# 0     17      64    316   Male  ...        False           False      False
# 1     35      85    299   Male  ...        False           False      False
# 2     84      65    406   Male  ...        False           False      False
# 3     55      95    436   Male  ...        False           False      False
# 4    100      56    526   Male  ...        False           False      False
#
#   Symbiote Costume Speed Force  Phoenix Force  Molecular Dissipation  \
# ...

# %%
columns = df.columns
for c in columns:
    print (c)
# Out:
# Name
# Alignment
# Intelligence_x
# Strength
# Speed
# Durability_x
# Power
# Combat
# Total
# Gender
# EyeColor
# Race
# HairColor
# Publisher
# SkinColor
# Height
# Weight
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# Element Control
# Phasing
# ...

# %%
df.count()
# Out:
# Name                     534
# Alignment                531
# Intelligence_x           534
# Strength                 534
# Speed                    534
#                         ...
# Phoenix Force            534
# Molecular Dissipation    534
# Vision - Cryo            534
# Omnipresent              534
# Omniscient               534
# Length: 182, dtype: int64

# %%
df.drop(['Intelligence_x', 'Strength', 'Speed', 'Durability_x', 'Power', 'Total', 'Gender', 'EyeColor', 'Race', 'HairColor', 'Publisher', 'Height', 'Weight', 'Agility'], axis=1, inplace=True)

# %%
df.head()
# Out:
#           Name Alignment  Combat SkinColor  Accelerated Healing  \
# 0       A-Bomb      good      64         -                 True
# 1   Abe Sapien      good      85      blue                 True
# 2     Abin Sur      good      65       red                False
# 3  Abomination       bad      95         -                 True
# 4      Abraxas       bad      56         -                False
#
#    Lantern Power Ring  Dimensional Awareness  Cold Resistance  Stealth  \
# 0               False                  False            False    False
# 1               False                  False             True    False
# 2                True                  False            False    False
# 3               False                  False            False    False
# 4               False                   True            False    False
#
#    Energy Absorption  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False  ...         False            False       False
# ...

# %%
df.drop(['Combat', 'SkinColor'], axis=1, inplace=True)

# %%
df.head()
# Out:
#           Name Alignment  Accelerated Healing  Lantern Power Ring  \
# 0       A-Bomb      good                 True               False
# 1   Abe Sapien      good                 True               False
# 2     Abin Sur      good                False                True
# 3  Abomination       bad                 True               False
# 4      Abraxas       bad                False               False
#
#    Dimensional Awareness  Cold Resistance  Stealth  Energy Absorption  Flight  \
# 0                  False            False    False              False   False
# 1                  False             True    False              False   False
# 2                  False            False    False              False   False
# 3                  False            False    False              False   False
# 4                   True            False    False              False    True
#
#    Danger Sense  ...  Web Creation  Reality Warping  Odin Force  \
# ...

# %%
good_df = df.loc[(df['Alignment'] == "good")]
good_df.head()
# Out:
#            Name Alignment  Accelerated Healing  Lantern Power Ring  \
# 0        A-Bomb      good                 True               False
# 1    Abe Sapien      good                 True               False
# 2      Abin Sur      good                False                True
# 5   Adam Monroe      good                 True               False
# 6  Adam Strange      good                False               False
#
#    Dimensional Awareness  Cold Resistance  Stealth  Energy Absorption  Flight  \
# 0                  False            False    False              False   False
# 1                  False             True    False              False   False
# 2                  False            False    False              False   False
# 5                  False            False    False              False   False
# 6                  False            False     True              False    True
#
#    Danger Sense  ...  Web Creation  Reality Warping  Odin Force  \
# ...

# %%
columns = good_df.columns
for c in columns:
    print (c)
# Out:
# Name
# Alignment
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# Element Control
# Phasing
# Astral Projection
# Electrical Transport
# Fire Control
# Projection
# Summoning
# Enhanced Memory
# Reflexes
# Invulnerability
# Energy Constructs
# Force Fields
# ...

# %%
good_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369 entries, 0 to 532
# Columns: 166 entries, Name to Omniscient
# dtypes: bool(164), object(2)
# memory usage: 67.7+ KB

# %%
bad_df = df.loc[(df['Alignment'] == "bad")]
bad_df.head()
# Out:
#            Name Alignment  Accelerated Healing  Lantern Power Ring  \
# 3   Abomination       bad                 True               False
# 4       Abraxas       bad                False               False
# 9    Air-Walker       bad                False               False
# 13        Amazo       bad                False                True
# 14         Ammo       bad                False               False
#
#     Dimensional Awareness  Cold Resistance  Stealth  Energy Absorption  \
# 3                   False            False    False              False
# 4                    True            False    False              False
# 9                   False            False    False              False
# 13                  False            False    False              False
# 14                  False            False    False              False
#
#     Flight  Danger Sense  ...  Web Creation  Reality Warping  Odin Force  \
# ...

# %%
nuetral_df = df.loc[(df['Alignment'] == "nuetral")]
nuetral_df.head()
# Out:
# Empty DataFrame
# ...

# %%
def label_powers (row):
    if row[] in ['New York', 'Pennsylvania', 'New Jersey']:
        return 'mental'
    if row['state'] in ['Wisconsin', 'Michigan', 'Illinois', 'Indiana', 'Ohio', 'North Dakota', 'South Dakota', 'Nebraska', 'Kansas', 'Minnesota', 'Iowa', 'Missouri']:
        return 'speed_flight'
    if row['state'] in ['Delaware', 'Maryland', 'District of Columbia', 'Virginia', 'West Virginia', 'North Carolina', 'South Carolina', 'Georgia', 'Florida', 'Kentucky', 'Tennessee', 'Mississippi', 'Alabama', 'Oklahoma', 'Texas', 'Arkansas', 'Louisiana']:
        return 'south'
    return 'etc'

good_df['label'] = good_df.apply(lambda row: label_powers(row), axis=1)

good_df
